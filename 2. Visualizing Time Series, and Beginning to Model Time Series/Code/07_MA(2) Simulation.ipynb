# %% [markdown]
# # Simulating MA(2) process for the next video lecture
# ## Following codes are executed in R in the video lecture

# %% [markdown]
# Vamos a generar ruido:

# %%
# Generate noise
noise=rnorm(10000)

# %%
# Introduce a variable
ma_2=NULL

# Loop for generating MA(2) process
for(i in 3:10000){
    ma_2[i]=noise[i]+0.7*noise[i-1]+0.2*noise[i-2]
}

# %%
# Shift data to left by 2 units (porque los dos primeros puntos son nulos)
moving_average_process=ma_2[3:10000]

# %%
# Put time series structure on a vanilla data
moving_average_process=ts(moving_average_process)

# %% [markdown]
# Graficamos:

# %%
# Partition output graphics as a multi frame of 2 rows and 1 column
par(mfrow=c(2,1))

# plot the process and plot its ACF
plot(moving_average_process, main='A moving average process of order 2', ylab=' ', col='blue')
acf(moving_average_process, main='Correlogram of a moving average process of order 2')
# Out:
# Plot with title “Correlogram of a moving average process of order 2”

# %% [markdown]
# Tenemos correlación con el lag 1 (tiene sentido) y con el lag 2, y después nada. Esto es muy característico de los $MA(q)$: si tengo correlación con los q primeros lags.

# %% [markdown]
# Por tanto, si nosotros tenemos una serie temporal y vemos en el ACF que a partir de cierto lag ya no hay correlación, la modelaremos con un $MA(q)$.
